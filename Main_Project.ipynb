# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 1 |</span><span style='color:coralred'> Introduction</span></b>
#
# ____
#
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 1.1. Bussiness Context</span></b>
#
# Industri ritel adalah sektor yang dinamis dan selalu berubah, dengan estimasi ukuran pasar global mencapai puluhan triliun. Tren utama meliputi meningkatnya adopsi teknologi e-commerce, pentingnya pengalaman pelanggan yang dipersonalisasi, dan pergeseran ke model omnichannel. Dalam lingkungan yang kompetitif ini, jenis retail **Supermarket** menghadapi persaingan dari jenis retil berskala besar seperti **HyperMart**, yang dikenal dengan jaringan toko fisik yang luas dan strategi harga yang agresif, serta indsutri **Groceries** sekarang ini, pemimpin dalam layanan pengiriman berbasis aplikasi. Untuk mempertahankan keunggulan kompetitif, **Supermarket** berfokus pada inovasi berkelanjutan, kemitraan strategis, dan pemahaman mendalam tentang kebutuhan pelanggan.
#
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 1.2. Problem Statement</span></b>
#
# Data **Supermarekt** ini memiliki 67.68% customer dengan `Nilai Recency` berada pada nilai yang tinggi, membuat problem ini menjadi Main Point untuk segera diselesaikan.
#
# **Recency menjadi faktor kuat dan menyebabkan Probabilitas Churn yang tinggi**
# dan perusahaan tidak bisa sepenuhnya menurunkan `Nilai Recency` tanpa memastikan aksesibilitas dan service mencapai seluruh user. Sederhananya, jika perusahaan tidak segera mengevaluasi dan meningkatkan Service mereka, maka `Nilai Recency` yang tinggi akan mengakibatkan persentase `Churn` yang tinggi.
#
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 1.3. Bussiness Task</span></b>
#
# **Bagaimana Cara Menurunkan Nilai Recency Customer?**
# Recency dengan Nilai lebih dari 30, menandakan pelanggan tidak kembali pada 1 bulan terkahir (berlaku kelipatannya) dan itu menjadi indikator bahwa kesehatan mengelola pelanggan yang kurang ideal. Tingkat `Churn` ideal untuk perusahaan yang matang dan mapan adalah 5% hingga 7% dalam churn tahunan dan kurang dari 1% dalam churn bulanan. Jika perusahaan memiliki 1.000 pelanggan, ini berarti kita hanya akan kehilangan 50 pelanggan per tahun atau empat hingga lima Customer per bulan.
#
# Oleh karena itu, diperlukan strategi yang komprehensif untuk mengidentifikasi dan menangani faktor-faktor yang mempengaruhi `Recency`.
# Ada 4 hal utama yang menjadi fokus pada hubungan antara `Nilai Recency` yang rendah dengan faktor lainya:
#
# #### 1. Customer Demographics
#
# #### 2. Customer Income and Spending
#
# #### 3. Purchase Behavior
#
# #### 4. Promotion Response
#
# Analisis ini akan fokus pada Customer Demographic, Purchase Behaviour, Engagement Metrics (Promotion Response). Pelanggan dengan keterlibatan lebih dari 30 hari (1 Bulan) akan diprioritaskan untuk mencerminkan pola interaksi yang berarti, yang artinya pada analisis ini akan menaruh batas (threshold) pada angka 30 untuk mencerminkan standar `Churn` potential diatas angka tersebut. Secara khusus, analisis ini bertujuan untuk mengidentifikasi pain point dalam faktor `Recency` yang mempengaruhi loyalitas dan **mencapai pengurangan 0.5% dalam churn selama tahun fiskal berikutnya**.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 1.4. Stake Holder</span></b>
#
# * Store Manajer Supermarket
#
# * Marketing Team Supermarket
#
# * Customer Supermarket

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 1.5. Scenario</span></b>
#
# **Data yang Akurat dan Relevan:**
# * Asumsi: Data yang digunakan dalam analisis adalah akurat dan mencerminkan kondisi nyata pelanggan supermarket.
# * Rasionalisasi: Berdasarkan pengumpulan data yang teliti dan validasi awal terhadap dataset.
# * Dampak: Jika data tidak akurat, hasil analisis bisa menyesatkan dan mengarah pada keputusan yang salah.
#
# **Campaign Promosi Diterima dengan Baik:**
# * Asumsi: Pelanggan yang menerima penawaran Campaign cenderung memiliki nilai Recency yang lebih rendah.
# * Rasionalisasi: Berdasarkan teori pemasaran bahwa penawaran yang menarik dapat meningkatkan frekuensi pembelian.
# * Dampak: Campaign yang tidak efektif dapat menyebabkan pengeluaran yang tidak efisien dan tidak meningkatkan Recency.
#
# **Distribusi Pendapatan yang Tepat:**
# * Asumsi: Distribusi pendapatan pelanggan menunjukkan pola yang mewakili populasi pelanggan supermarket.
# * Rasionalisasi: Berdasarkan statistik yang menunjukkan persebaran pendapatan dalam dataset.
# * Dampak: Analisis pendapatan yang bias dapat mengarah pada strategi pemasaran yang tidak tepat sasaran.

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 2 |</span><span style='color:coralred'> Data Examination</span></b>
#
# ____

# %%
# Kumpulan pustaka yang akan dipakai
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy as cp
import warnings
warnings.filterwarnings('ignore')

# Kumpulan Option yang akan dipakai
pd.options.display.max_colwidth = 1
pd.options.display.max_columns = 29

# %%
# Import data yang ingin diproses
df = pd.read_csv('Database/Supermarket Customers_Raw.csv', delimiter='\t')
print(f'Data ini berisi {len(df.columns)} kolom dan {len(df)} baris, diantarnya terdapat {df.duplicated().sum()} data duplikat.')
print("Data Sample:")
df.sample(2)
# Out:
# Data ini berisi 29 kolom dan 2240 baris, diantarnya terdapat 0 data duplikat.
# Data Sample:
#         ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 180   7698  1976        PhD         Married        51650.0  0        1
# 1567  4390  1954        Graduation  Together       75315.0  0        1
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 180   11-05-2014  81       152       3          22
# 1567  15-04-2014  14       459       15         171
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 180   2                5                 7             1
# 1567  142              23                31            2
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 180   4                1                    4
# 1567  5                4                    12
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 180   5                  0             0             0
# ...

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 2.1. About the Data</span></b>
# Dataset ini berisi informasi terkait Customer, Product, Promotion, dan Purchase Place. Ada **29 Kolom**, **2240 Baris** dan diantaranya tidak ada **0 Duplikat** di dalam dataset Supermarket Customers, yaitu:
#
# **Customer**
# * `ID` : ID unik untuk setiap customer
# * `Year_Birth` : (Tahun) Birthday Customer
# * `Education` : Customer Education Level
# * `Marital_Status` : Customer Marital_Status
# * `Income` : Income tahunan customer
# * `Kidhome` : Total anak kecil yang dimiliki customer
# * `Teenhome` : Total remaja yang dimiliki customer
# * `Dt_Customer` : Tanggal pendaftaran customer (first enroll atau pembelian pertama)
# * `Recency` : Jumlah hari sejak pembelian terakir customer
# * `Complain` : 1 jika pelanggan mengeluh dalam 2 tahun terakhir, 0 sebaliknya
#
# **Product**
# * `MntWines` : Jumlah pembelian anggur dalam 2 tahun terakir
# * `MntFruits` : Jumlah pembelian buah dalam 2 tahun terakir
# * `MntMeatProducts` : Jumlah pembelian daging dalam 2 tahun terakir
# * `MntFishProducts` : Jumlah pembelian ikan dalam 2 tahun terakir
# * `MntSweetProducts` : Jumlah pembelian permen dalam 2 tahun terakir
# * `MntGoldProds` : Jumlah pembelian emas dalam 2 tahun terakir
#
# **Promotion**
# * `NumDealsPurchases` : Jumlah pembelian yang dilakukan dengan diskon
# * `AcceptedCmp1` : 1 jika pelanggan menerima penawaran di Campaign 1st, 0 jika tidak
# * `AcceptedCmp2` : 1 jika pelanggan menerima penawaran di Campaign 2nd, 0 jika tidak
# * `AcceptedCmp3` : 1 jika pelanggan menerima penawaran di Campaign 3rd, 0 jika tidak
# * `AcceptedCmp4` : 1 jika pelanggan menerima penawaran di Campaign 4th, 0 jika tidak
# * `AcceptedCmp5` : 1 jika pelanggan menerima penawaran di Campaign 5th, 0 jika tidak
# * `Response` : 1 jika pelanggan menerima penawaran di Campaign terakhir, 0 jika tidak
#
# **Purchase_Place**
# * `NumWebPurchases` : Jumlah pembelian yang dilakukan melalui website supermarket
# * `NumCatalogPurchases` : Jumlah pembelian yang dilakukan melalui catalog
# * `NumStorePurchases` : Jumlah pembelian yang dilakukan melalui datang langsung ke supermarket
# * `NumWebVisitsMonth` :Jumlah kunjungan ke situs web supermarket dalam sebulan terakhir
#
# Terdapat kolom Z_CostContact dan Z_Revenue yang berisi 1 value dan tidak ada penjelasan lebih lanjut terkait value dari kolom ini.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 2.2. Data Assesment</span></b>
#
# Sebelum masuk ke dalam analisis, kita perlu mengenal dataset kita lebih jauh dalam tahapan *data Assesment*. Dari proses ini, kita akan tahu anomali-anomali apa saja yang terdapat di dalam dataset kita dan perlu ditangani dalam tahapan *data cleaning*. Setiap penangan anomali yang dilakukan, akan disertai dengan justifikasi langkah yang diambil, baik secara *domain knowledge* maupun secara statistik.

# %% [markdown]
# <a id="basic"></a>
# ##### <b><span style='color:coralred'> 2.2.1. Data Size : Amount and Range</span></b>

# %%
# Memberikan penilaian awal terhadap dataset
cekiceki = pd.DataFrame({
    'Type': df.dtypes,
    'N/A (%)': df.isna().mean() * 100,
    'Unique': df.nunique(),
    'Sample': [df[col].unique() for col in df.columns]
})
display(cekiceki)
# Out:
#                         Type   N/A (%)  Unique  \
# ID                   int64    0.000000  2240
# Year_Birth           int64    0.000000  59
# Education            object   0.000000  5
# Marital_Status       object   0.000000  8
# Income               float64  1.071429  1974
# Kidhome              int64    0.000000  3
# Teenhome             int64    0.000000  3
# Dt_Customer          object   0.000000  663
# Recency              int64    0.000000  100
# MntWines             int64    0.000000  776
# MntFruits            int64    0.000000  158
# MntMeatProducts      int64    0.000000  558
# MntFishProducts      int64    0.000000  182
# MntSweetProducts     int64    0.000000  177
# MntGoldProds         int64    0.000000  213
# NumDealsPurchases    int64    0.000000  15
# NumWebPurchases      int64    0.000000  15
# NumCatalogPurchases  int64    0.000000  14
# NumStorePurchases    int64    0.000000  14
# NumWebVisitsMonth    int64    0.000000  16
# ...

# %%
# Menyalin dataframe
rangeofdata = cp.deepcopy(df)

# Mengubah kolom Dt_Customer menjadi format datetime
rangeofdata['Dt_Customer'] = pd.to_datetime(rangeofdata['Dt_Customer'], format='%d-%m-%Y')

# Menampilkan rentang tanggal
print(f'rentang tanggal data enroll customer dari {rangeofdata.Dt_Customer.min().strftime("%d-%m-%Y")} hingga {rangeofdata.Dt_Customer.max().strftime("%d-%m-%Y")}')
# Out:
# rentang tanggal data enroll customer dari 30-07-2012 hingga 29-06-2014

# %%
# membuat variabel uji coba
period_a_start = '2012-07-30'
period_a_end = '2013-06-30'
period_b_start = '2013-07-01'
period_b_end = '2014-06-29'

# mencari data yang sesuai dengan variabel uji coba
data_period_a = df[(df['Dt_Customer'] >= period_a_start) & (df['Dt_Customer'] <= period_a_end)]
data_period_b = df[(df['Dt_Customer'] >= period_b_start) & (df['Dt_Customer'] <= period_b_end)]

# menghitung jumlah tiap periode
churn_potential_a = data_period_a[data_period_a['Recency'] >= 30].shape[0]
churn_potential_b = data_period_b[data_period_b['Recency'] >= 30].shape[0]

# agg presentase Churn Potential YoY 
percentage_increase = ((churn_potential_b - churn_potential_a) / churn_potential_a) * 100

print(f"Churn potential pada Period A: {churn_potential_a}")
print(f"Churn potential pada Period B: {churn_potential_b}")
print(f"Kenaikan Percentage: {percentage_increase:.2f}%")
# Out:
# Churn potential pada Period A: 771
# Churn potential pada Period B: 777
# Kenaikan Percentage: 0.78%

# %%
# Menghitung jumlah total ID
total_ids = df['ID'].count()

# Menghitung jumlah ID dengan Recency di atas 30
above_30 = df.loc[df['Recency'] > 30, 'ID'].count()

# Menghitung jumlah ID dengan Recency di bawah atau sama dengan 30
below_30 = df.loc[df['Recency'] <= 30, 'ID'].count()

# Menghitung persentase
percentage_above_30 = (above_30 / total_ids) * 100
percentage_below_30 = (below_30 / total_ids) * 100

# Menampilkan hasil
print(f"Persentase Customer dengan Recency di atas 30 hari : {percentage_above_30:.2f}%")
print(f"Persentase Customer dengan Recency di bawah atau sama dengan 30 hari: {percentage_below_30:.2f}%")
# Out:
# Persentase Customer dengan Recency di atas 30 hari : 67.68%
# Persentase Customer dengan Recency di bawah atau sama dengan 30 hari: 32.32%

# %%
# Preview Statistik Deskriptif
display(df.describe(), df.describe(include='object'))
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count  2240.000000   2240.000000  2216.000000    2240.000000  2240.000000
# mean   5592.159821   1968.805804  52247.251354   0.444196     0.506250
# std    3246.662198   11.984069    25173.076661   0.538398     0.544538
# min    0.000000      1893.000000  1730.000000    0.000000     0.000000
# 25%    2828.250000   1959.000000  35303.000000   0.000000     0.000000
# 50%    5458.500000   1970.000000  51381.500000   0.000000     0.000000
# 75%    8427.750000   1977.000000  68522.000000   1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000  2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000  2240.000000
# mean   49.109375    303.935714   26.302232    166.950000
# std    28.962453    336.597393   39.773434    225.715373
# min    0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# <a id="basic"></a>
# ##### <b><span style='color:coralred'> 2.2.2. Data Condition: Quality and Representativeness</span></b>

# %%
from scipy.stats import shapiro

# variabel berisi column
columns = ['ID', 'Year_Birth', 'Income', 'Kidhome', 'Teenhome', 'Recency',
           'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
           'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
           'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
           'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
           'AcceptedCmp1', 'AcceptedCmp2', 'Complain', 'Z_CostContact',
           'Z_Revenue', 'Response']

# Membuat grid subplot
fig, axes = plt.subplots(6, 5, figsize=(20, 15))

# Meratakan array axes untuk iterasi yang mudah
axes = axes.flatten()

# Melakukan uji Shapiro-Wilk untuk setiap kolom dan membuat histogram
for i, column in enumerate(columns):
    ax = axes[i]
    # Cek apakah kolom adalah numerik; jika tidak, skip uji Shapiro-Wilk
    if pd.api.types.is_numeric_dtype(df[column]):
        sns.histplot(data=df, x=column, kde=True, label=column, ax=ax)
        ax.set_title(column)

        # Melakukan uji Shapiro-Wilk
        stat, p = shapiro(df[column])

        if p > 0.05:
            ax.set_xlabel(f"Shapiro-Wilk Test: p={p:.3f}\nNormal Distribution")
        else:
            ax.set_xlabel(f"Shapiro-Wilk Test: p={p:.3f}\nNot Normal Distribution")
    else:
        ax.set_xlabel("Non-numeric data")

# Menghapus subplot yang tidak digunakan
for i in range(len(columns), len(axes)):
    fig.delaxes(axes[i])

# Menyesuaikan tata letak dan menampilkan plot
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
box_plot1 = sns.boxplot(data=df[['Income']])
box_plot1.set_xticklabels(box_plot1.get_xticklabels(), fontsize=8)

plt.subplot(2, 2, 2)
box_plot2 = sns.boxplot(data=df[['Year_Birth']])
box_plot2.set_xticklabels(box_plot2.get_xticklabels(), fontsize=8)

plt.subplot(2, 2, 3)
box_plot3 = sns.boxplot(data=df[['MntFishProducts', 'MntSweetProducts','MntGoldProds','MntWines','MntFruits','MntMeatProducts']])
box_plot3.set_xticklabels(box_plot3.get_xticklabels(), fontsize=5.5)

plt.subplot(2, 2, 4)
box_plot4 = sns.boxplot(data=df[['NumDealsPurchases', 'NumWebPurchases','NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']])
box_plot4.set_xticklabels(box_plot4.get_xticklabels(), fontsize=5.7)

plt.show()

# %% [markdown]
# ### Anomali Missing Value pada kolom Income

# %%
# Menyalin dataframe
NaN_data = cp.deepcopy(df)

# Melihat semua jumlah NaN pada 'Income'
Nan = NaN_data.loc[df['Income'].isna()]
nanval = len(Nan)

print(f'nilai NaN pada kolom fitur Income sejumlah {nanval} item')
display(Nan)
# Out:
# nilai NaN pada kolom fitur Income sejumlah 24 item
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 10    1994   1983        Graduation  Married       NaN      1        0
# 27    5255   1986        Graduation  Single        NaN      1        0
# 43    7281   1959        PhD         Single        NaN      0        0
# 48    7244   1951        Graduation  Single        NaN      2        1
# 58    8557   1982        Graduation  Single        NaN      1        0
# 71    10629  1973        2n Cycle    Married       NaN      1        0
# 90    8996   1957        PhD         Married       NaN      2        1
# 91    9235   1957        Graduation  Single        NaN      1        1
# 92    5798   1973        Master      Together      NaN      0        0
# 128   8268   1961        PhD         Married       NaN      0        1
# 133   1295   1963        Graduation  Married       NaN      0        1
# ...

# %% [markdown]
# ### Anomali Nilai extreme kolom Income

# %%
# Melihat semua Anomali nilai Max pada 'Income'
df.sort_values(by='Income', ascending=False).head(5)
# Out:
#         ID  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 2233  9432  1977        Graduation  Together       666666.0  1
# 617   1503  1976        PhD         Together       162397.0  1
# 687   1501  1982        PhD         Married        160803.0  0
# 1300  5336  1971        Master      Together       157733.0  1
# 164   8475  1973        PhD         Married        157243.0  0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 2233  0         02-06-2013  23       9         14         18
# 617   1         03-06-2013  31       85        1          16
# 687   0         04-08-2012  21       55        16         1622
# 1300  0         04-06-2013  37       39        1          9
# 164   1         01-03-2014  98       20        2          1582
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 2233  8                1                 12            4
# 617   2                1                 2             0
# ...

# %% [markdown]
# ### Anomali kolom Education
# Isi dari kolom Education terdapat 2n Cycle, 2n Cycle akan kita asumsikan sebagai gelar Master, maka akan kita ubah menjadi Master
#
# * Basic dapat diasumsikan hanya memiliki pendidikan dasar dan belum punya gelar
# * Kolom Graduation dapat diasumsikan sebagai 1st Cycle
# * Kolom Master dapat diasumsikan sebagai 2nd Cycle
# * Kolom PhD dapat diasumsikan sebagai 3rd Cycle
#
# Untuk selanjutnya kita akan menggunakan 4 Status Education = Basic, Graduation, Master, dan PhD

# %%
# Hitung jumlah unik, total, dan persentase untuk 'Education'
education_summary = df['Education'].value_counts().reset_index()
education_summary.columns = ['Education', 'Total']
education_summary['Percentage'] = (education_summary['Total'] / len(df)) * 100

display(education_summary)
# Out:
#     Education  Total  Percentage
# 0  Graduation  1127   50.312500
# 1  PhD         486    21.696429
# 2  Master      370    16.517857
# 3  2n Cycle    203    9.062500
# 4  Basic       54     2.410714

# %% [markdown]
# ### Anomali Kolom Marital Status

# %%
# Hitung jumlah unik, total, dan persentase untuk 'Marital_Status'
marital_status_summary = df['Marital_Status'].value_counts().reset_index()
marital_status_summary.columns = ['Marital_Status', 'Total']
marital_status_summary['Percentage'] = (marital_status_summary['Total'] / len(df)) * 100

display(marital_status_summary)
# Out:
#   Marital_Status  Total  Percentage
# 0  Married        864    38.571429
# 1  Together       580    25.892857
# 2  Single         480    21.428571
# 3  Divorced       232    10.357143
# 4  Widow          77     3.437500
# 5  Alone          3      0.133929
# 6  Absurd         2      0.089286
# 7  YOLO           2      0.089286

# %% [markdown]
# ### Anomali Nilai extreme kolom Year Birth

# %%
# Melihat semua Anomali nilai Min pada 'Year_Birth'
df.sort_values(by='Year_Birth').head(10)
# Out:
#          ID  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 239   11004  1893        2n Cycle  Single         60182.0  0        1
# 339   1150   1899        PhD       Together       83532.0  0        0
# 192   7829   1900        2n Cycle  Divorced       36640.0  1        0
# 1950  6663   1940        PhD       Single         51141.0  0        0
# 424   6932   1941        PhD       Married        93027.0  0        0
# 1150  1453   1943        PhD       Widow          57513.0  0        0
# 415   7106   1943        PhD       Married        75865.0  0        0
# 2084  5250   1943        Master    Widow         NaN       0        0
# 358   6142   1943        Master    Married        65073.0  0        0
# 1923  4994   1943        Master    Single         77598.0  0        0
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 239   17-05-2014  23       8         0          5
# 339   26-09-2013  36       755       144        562
# ...

# %% [markdown]
# ##### Key Cleansing
# *Dataset Supermarket Customers memiliki 29 kolom dan 2.240 baris.*
# **Secara keseluruhan, kita bisa melihat bahwa :**
#
# * Kolom `Dt_Customer` memiliki tipe data object yang akan kita rubah menjadi tipe data datetime
#
# * Kolom `Education` memiliki tipe data object yang akan kita rubah menjadi tipe data Category
#
# * Kolom `Marital_Status` memiliki tipe data object yang akan kita rubah menjadi tipe data Category
#
# * Kolom `Income` memiliki data kosong sebesat 1.07% atau sebanyak 24 item. Data kosong pada kolom tersebut diwakili dengan data **NaN**.
#
# * Pada Kolom `Income` terdapat anomali inputan yang dimana nilai maksimal dari data `Income` adalah **666.666**.
#
# * Kolom `Z_CostContact` dan `Z_Revenue` tidak bisa dijelaskan menggunakan **Domain Knowledge** dan hanya terdapat 1 value saja sehingga kita asumsikan kedua kolom tersebut tidak digunakan.
#
# * Kolom `Education` penulisan 2n Cycle kita ubah menjadi Master. Source [Reference](https://www.studera.nu/startpage/higher-education/sweden/levels-degrees/)
#
# * Kolom `Marital_Status`, terdapat Alone, Absurd, dan YOLO yang akan kita gabungkan menjadi Single dan status Together akan kita ubah menjadi Married. Sehingga hasil akhir dari kolom Martial hanya ada 4 opsi **yaitu** : ***Single, Married, Divorced, Widow***
#
# * Kolom `Year_Birth` ada 3 inputan berisi **1893,1899,1900**. Dimana artinya kemungkinan ada kesalahan input saat pendaftaran customer.
#
# * Kolom `Generasi`ditambahkan sebagai alat bantu analisis, akan dibagi menjadi 5 opsi **yaitu** : ***Gen z, Milenial, Gen X, Boomers, Silent*** . Source [Reference](https://www.pewresearch.org/short-reads/2019/01/17/where-millennials-end-and-generation-z-begins/)
#
# * Hampir setiap fitur kolom mempunyai nilai outlier yang extreme, itu akan mengakibatkan hasil dari anilisis yang kurang ideal

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 3 |</span><span style='color:coralred'> Data Transformation</span></b>
#
# ____

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 3.1. Data Cleaning</span></b>
# kita akan menggunakan setiap poin dari Key Cleansing sebagai tahapan Data Cleaning

# %%
# Mengubah Tipe dari kolom Dt_Customer
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'], format='%d-%m-%Y')

# %%
# Mengisi NaN value dari kolom Income dengan median dari setiap kategori kolom Education & Marital_Status 
df['Income'] = df['Income'].fillna(df.groupby(['Education', 'Marital_Status'])['Income'].transform('median'))

# %%
# Mengisi Nilai extreme dari kolom Income dengan median dari setiap kategori kolom Education & Marital_Status 
df.loc[df['Income'] > 150000, 'Income'] = df.groupby(['Education', 'Marital_Status'])['Income'].transform('median')

# %%
# Membuang Kolom yang tidak dieprlukan
columns_to_drop = ['Z_CostContact', 'Z_Revenue']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Response'],
#       dtype='object')

# %%
# Mengubah nilai 2n Cycle menjadi Master dan Graduation menjadi Bachelor
df.loc[df['Education'] == '2n Cycle', 'Education'] = 'Master'
df.loc[df['Education'] == 'Graduation', 'Education'] = 'Bachelor'
df['Education'].unique()
# Out:
# array(['Bachelor', 'PhD', 'Master', 'Basic'], dtype=object)

# %%
# Perubahan Alone, Absurd, YOLO menjadi Single
merge_single = ['Alone','Absurd','YOLO']
df['Marital_Status'] = df['Marital_Status'].replace(merge_single,'Single')


# Perubahan Together menjadi Married
df['Marital_Status'] = df['Marital_Status'].replace('Together','Married')

df['Marital_Status'].unique()
# Out:
# array(['Single', 'Married', 'Divorced', 'Widow'], dtype=object)

# %%
# Mengisi nilai extreme dari kolom Year_Birth dengan median dari setiap kategori kolom Education & Marital_Status 
df.loc[df['Year_Birth'] <= 1940, 'Year_Birth'] = df.groupby(['Education', 'Marital_Status'])['Year_Birth'].transform('median')

# %% [markdown]
# ### Menangani Outlier pada Kategori Ammount

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Response'],
#       dtype='object')

# %%
def winsorize(data, lower_percentile=0.10, upper_percentile=0.90):
    lower_limit = data.quantile(lower_percentile)
    upper_limit = data.quantile(upper_percentile)
    data_cleaned = data.clip(lower=lower_limit, upper=upper_limit)
    return data_cleaned

AWines = winsorize(df['MntWines'])
df['MntWines'] = AWines

AFruits = winsorize(df['MntFruits'])
df['MntFruits'] = AFruits

AMeat = winsorize(df['MntMeatProducts'])
df['MntMeatProducts'] = AMeat

AFish =winsorize(df['MntFishProducts'])
df['MntFishProducts'] = AFish

ASweet = winsorize(df['MntSweetProducts'])
df['MntSweetProducts'] = ASweet

AGold = winsorize(df['MntGoldProds'])
df['MntGoldProds'] = AGold

# %% [markdown]
# ### Menangani Outlier pada Kategori Num Coloumns

# %%
def winsorize(data, lower_percentile=0.10, upper_percentile=0.90):
    lower_limit = data.quantile(lower_percentile)
    upper_limit = data.quantile(upper_percentile)
    data_cleaned = data.clip(lower=lower_limit, upper=upper_limit)
    return data_cleaned

BDeal = winsorize(df['NumDealsPurchases'])
df['NumDealsPurchases'] = BDeal

BWeb = winsorize(df['NumWebPurchases'])
df['NumWebPurchases'] = BWeb

BCata = winsorize(df['NumCatalogPurchases'])
df['NumCatalogPurchases'] = BCata

BStore = winsorize(df['NumStorePurchases'])
df['NumStorePurchases'] = BStore

BVisit = winsorize(df['NumWebVisitsMonth'])
df['NumWebVisitsMonth'] = BVisit

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
box_plot1 = sns.boxplot(data=df[['Income']])
box_plot1.set_xticklabels(box_plot1.get_xticklabels(), fontsize=8)  # Sesuaikan ukuran font sesuai kebutuhan Anda

plt.subplot(2, 2, 2)
box_plot2 = sns.boxplot(data=df[['Year_Birth']])
box_plot2.set_xticklabels(box_plot2.get_xticklabels(), fontsize=8)  # Sesuaikan ukuran font sesuai kebutuhan Anda

plt.subplot(2, 2, 3)
box_plot3 = sns.boxplot(data=df[['MntFishProducts', 'MntSweetProducts','MntGoldProds','MntWines','MntFruits','MntMeatProducts']])
box_plot3.set_xticklabels(box_plot3.get_xticklabels(), fontsize=5.5)  # Sesuaikan ukuran font sesuai kebutuhan Anda

plt.subplot(2, 2, 4)
box_plot4 = sns.boxplot(data=df[['NumDealsPurchases', 'NumWebPurchases','NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']])
box_plot4.set_xticklabels(box_plot4.get_xticklabels(), fontsize=5.7)  # Sesuaikan ukuran font sesuai kebutuhan Anda

plt.show()

# %%
# Mengubah Tipe dari kolom Education, Marital_Status
df['Education'] = df['Education'].astype('category')
df['Marital_Status'] = df['Marital_Status'].astype('category')

# %%
df['Income'].isna().sum()
# Out:
# 0

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 3.2. Data Creating</span></b>
#
# kita akan menggunakan setiap poin dari Key Question sebagai aspek pendukung agar analisis ideal, dengan Data Creation atau Binning

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Response'],
#       dtype='object')

# %%
# Menambah Kolom 'Age' 
current_year = df['Dt_Customer'].max().year
df.insert(2, 'Age', current_year-df['Year_Birth'])

# %%
# Menambah Kolom 'Generasi'
df.insert(3, 'Generasi', pd.cut(df['Age'], bins=[-np.inf, 22, 38, 54, 73], labels=['Gen Z', 'Milennial', 'Gen X', 'Boomers']))

# %%
# Menambah Kolom 'Ecomonic Stat' berdasarkan Quartiles (q)
df.insert(7, 'Economic_Stat', pd.qcut(df['Income'], q=4, labels=['Lowest', 'Low', 'High', 'Highest']))

# %%
# Menambah Kolom 'Dependent'
df.insert(10, 'Dependent', df['Kidhome'] + df['Teenhome'])

# %%
# Menambah Kolom 'mnttotal dari kolom 'MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds
df.insert(19, 'mnttotal', df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds'])

# %%
# Menambah Kolom 'totalpurchases dari kolom NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases
df.insert(25, 'totalpurchases', df['NumDealsPurchases'] + df['NumWebPurchases'] + df['NumCatalogPurchases'] + df['NumStorePurchases'])

# %%
# Menambah Kolom 'totalacceptedcmp dari kolom AcceptedCmp1, AcceptedCmp2, AcceptedCmp3, AcceptedCmp4, AcceptedCmp5, Response
df.insert(31, 'totalacceptedcmp', df['AcceptedCmp1'] + df['AcceptedCmp2'] + df['AcceptedCmp3'] + df['AcceptedCmp4'] + df['AcceptedCmp5'] + df['Response'])

# %%
# Merubah urutan Dataframe AcceptedCmp1 dan AcceptedCmp2 sebelum AcceptedCmp3
df = df[['ID', 'Year_Birth', 'Age', 'Generasi', 'Education', 'Marital_Status',
       'Income', 'Economic_Stat', 'Kidhome', 'Teenhome', 'Dependent',
       'Dt_Customer', 'Recency',  'Complain', 'MntWines', 'MntFruits', 'MntMeatProducts',
       'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'mnttotal',
       'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
       'NumStorePurchases', 'NumWebVisitsMonth', 'totalpurchases','AcceptedCmp1',
       'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 
       'Response', 'totalacceptedcmp']]

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Age', 'Generasi', 'Education', 'Marital_Status',
#        'Income', 'Economic_Stat', 'Kidhome', 'Teenhome', 'Dependent',
#        'Dt_Customer', 'Recency', 'Complain', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'mnttotal', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'totalpurchases', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'totalacceptedcmp'],
#       dtype='object')

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 4 |</span><span style='color:coralred'> Data Exploration</span></b>
#
# ____

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 4.1. Customer Demographic </span></b>

# %% [markdown]
# * Bagaimana hubungan usia customer dengan Recency?
# * Bagaimana pengaruh tingkat pendidikan terhadap Recency?

# %%
# Scatter Plot: Usia vs Recency
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Recency'], color='blue', alpha=0.5)
plt.title('Age vs Recency', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Recency', fontsize=12)
# plt.grid(True)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: **Scatter Plot of Age vs Recency**: Menampilkan hubungan antara usia pelanggan dan nilai Recency. Grafik ini membantu melihat apakah ada pola atau kecenderungan tertentu antara usia dan seberapa baru mereka berbelanja.
#
# * ini mengkonfirmasi bahwa tidak ada hubungan yang signifikan antara `Age` dan `Recency`. Usia seseorang tidak dapat dijadikan indikator yang ideal untuk seberapa baru `Recency` mereka berdasarkan data yang disajikan.

# %%
df['Generasi'].value_counts().reset_index()
# Out:
#     Generasi  count
# 0  Gen X      979
# 1  Milennial  667
# 2  Boomers    566
# 3  Gen Z      28

# %%
# Box Plot: Usia vs Recency (by Generasi)
plt.figure(figsize=(10, 6))
sns.boxplot(x='Generasi', y='Recency', data=df, palette='Blues')
plt.title('Generasi vs Recency', fontsize=14)
plt.xlabel('Generasi', fontsize=12)
plt.ylabel('Recency', fontsize=12)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: **Box Plot of Genearasi vs Recency**: Menampilkan distribusi nilai Recency di berbagai kelompok usia.
#
# * Setiap generasi memiliki variasi `Recency` yang luas, mencerminkan bahwa usia atau generasi tidak menjadi penentu yang signifikan dalam nilai `Recency`.

# %%
df['Education'].value_counts().reset_index()
# Out:
#   Education  count
# 0  Bachelor  1127
# 1  Master    573
# 2  PhD       486
# 3  Basic     54

# %%
# Box Plot: Pendidikan vs Recency
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education', y='Recency', data=df, palette='Reds')
plt.title('Education Level vs Recency', fontsize=14)
plt.xlabel('Education Level', fontsize=12)
plt.ylabel('Recency', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: **Box Plot of Education vs Recency**: Menampilkan distribusi nilai Recency untuk setiap tingkat pendidikan.

# %%
# Memeriksa distribusi Recency dan korelasi dengan Age dan Recency

# menganalisis hubungan antara umur dan recency
age_recency_corr = df[['Age', 'Recency']].corr()

# Grouping by Average berdasarkan Educaton untuk Recency
education_recency = df.groupby('Education')['Recency'].mean().reset_index()

display(age_recency_corr, education_recency)
# Out:
#               Age   Recency
# Age      1.000000  0.017989
# Recency  0.017989  1.000000
#   Education    Recency
# 0  Bachelor  50.035492
# 1  Basic     48.444444
# 2  Master    47.881326
# 3  PhD       48.483539

# %% [markdown]
# <span style='color:green'><b>Notes</b></span>:
# * Korelasi antara `Age` dan `Recency` adalah sekitar 0,017 sekian, menunjukkan **korelasi positif yang lemah**. Ini menunjukkan bahwa seiring bertambahnya usia, `Recency` hampir tidak akan meningkat, korelasi ini tidak cukup kuat untuk memberikan informasi yang berguna.
#
# * Pelanggan dengan gelar Bachelor cenderung memiliki `Recency` yang sedikit lebih tinggi dibandingkan dengan tingkat pendidikan Basic maupun PhD, sementara mereka yang hanya memiliki pendidikan Master memiliki `Recency` yang sedikit lebih rendah.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 4.2. Customer Income & Spending </span></b>

# %% [markdown]
# * Bagaimana distribusi pendapatan di antara customer dengan `Recency` rendah?
# * Apakah ada korelasi antara pendapatan dan total pembelian produk (MntWines, MntFruits, MntMeatProducts, dll) dengan `Recency`?

# %%
# Histogram: Distribusi Pendapatan dengan Recency rendah
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Recency'] <= 30]['Income'], kde=True, color='blue')
plt.title('Distribusi Pendapatan dengan Recency rendah (<= 30)', fontsize=14)
plt.xlabel('Income', fontsize=12)
plt.ylabel('Density', fontsize=12)
# plt.grid(True)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: Histogram ini menunjukkan distribusi pendapatan di antara pelanggan dengan Recency rendah.
# * Sebagian besar pelanggan dengan `Recency` kurang dari 30 hari memiliki bentuk Distribusi cenderung normal dan menunjukkan sedikit skewness ke kanan, yang menunjukkan bahwa ada beberapa pelanggan dengan pendapatan yang sangat tinggi, meskipun jumlahnya lebih sedikit.

# %%
# Box Plot: Pendapatan untuk pelanggan dengan Recency rendah dan tinggi
plt.figure(figsize=(10, 6))
df['Recency_Category'] = ['Low Recency' if x <= 30 else 'High Recency' for x in df['Recency']]
sns.boxplot(x='Recency_Category', y='Income', data=df, palette='Reds')
plt.title('Income by Recency Category', fontsize=14)
plt.xlabel('Recency Category', fontsize=12)
plt.ylabel('Income', fontsize=12)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: Box plot ini membandingkan distribusi pendapatan antara pelanggan dengan Recency rendah dan tinggi.
#
# * Pendapatan di kedua kategori `Recency` (High dan Low) memiliki distribusi yang sangat mirip. Ini menunjukkan bahwa kategori `Recency` tidak memberikan perbedaan yang signifikan dalam distribusi `Income`.
# * Baik pelanggan dengan **High Recency maupun Low Recency** memiliki rentang pendapatan yang serupa, dengan median dan rentang interkuartil yang hampir identik.
#
# ini menunjukkan bahwa tidak ada perbedaan yang signifikan dalam `Income` di antara pelanggan dengan **High Recency dan Low Recency**.

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Age', 'Generasi', 'Education', 'Marital_Status',
#        'Income', 'Economic_Stat', 'Kidhome', 'Teenhome', 'Dependent',
#        'Dt_Customer', 'Recency', 'Complain', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'mnttotal', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'totalpurchases', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'totalacceptedcmp',
#        'Recency_Category'],
#       dtype='object')

# %%
# Scatter Plot: Pendapatan vs Total Pembelian Produk dengan Recency
plt.figure(figsize=(10, 6))
plt.scatter(df['Income'], df['mnttotal'], c=df['Recency'], cmap='coolwarm', alpha=0.5)
plt.title('Income vs Total Product Spending terhadap Recency', fontsize=14)
plt.xlabel('Income', fontsize=12)
plt.ylabel('Total Product Spending', fontsize=12)
plt.colorbar(label='Recency')
plt.grid(True)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: Scatter plot ini menunjukkan hubungan antara pendapatan dan total pembelian produk, dengan Recency diwakili oleh warna.
#
# * Ada korelasi positif yang jelas antara `Income` dan pengeluaran produk.
# * `Recency` memberikan variasi dalam pola, tetapi tidak menunjukkan pengaruh yang sangat dominan dalam hubungan antara pendapatan dan pengeluaran.
# * Pelanggan dengan pengeluaran yang sangat tinggi cenderung memiliki `Recency` yang lebih rendah, yang menunjukkan bahwa mereka mungkin baru-baru ini melakukan pembelian besar.

# %%
# Heatmap: Korelasi antara Pendapatan, Total Pembelian Produk, dan Recency
plt.figure(figsize=(10, 6))
corr_matrix = df[['Income', 'mnttotal', 'Recency']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='RdBu', center=0)
plt.title('Correlation Income, Total Spending, dan Recency', fontsize=14)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: Heatmap ini menampilkan korelasi antara pendapatan, total pembelian produk, dan Recency.
#
# * Satu-satunya hubungan kuat yang terlihat di sini adalah antara `Income` dan total pengeluaran, dengan korelasi sebesar 0.83.
# * Hubungan antara `Recency` dengan kedua variabel lainnya (**Income dan mnttotal**) sangat lemah.
# * hampir tidak ada yang menunjukkan bahwa waktu sejak pembelian terakhir tidak terkait erat dengan `Income` atau total `Spending`.
#
# jelas bahwa pendapatan sangat berkorelasi dengan total pengeluaran, `Recency` tidak memainkan peran signifikan dalam hubungan ini.

# %%
# Filtering antara customer dengan low Recency
low_recency_customers = df[df['Recency'] <= 30]

# Distribusi Income diantar para Low Recency
income_distribution_low_recency = low_recency_customers['Income'].describe()

# korelasi antara income dan total product purchases (recency relation)
product_columns = ['Income', 'totalpurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']
income_purchases_corr = df[product_columns].corr()['Income'].drop('Income')

display(income_distribution_low_recency, income_purchases_corr)
# Out:
# count    724.000000
# mean     51894.633287
# std      20688.890742
# min      4023.000000
# 25%      35376.000000
# 50%      50954.500000
# 75%      68787.000000
# max      113734.000000
# Name: Income, dtype: float64
# totalpurchases         0.721580
# NumWebPurchases        0.543270
# NumCatalogPurchases    0.758411
# NumStorePurchases      0.693924
# Name: Income, dtype: float64

# %% [markdown]
# <span style='color:green'><b>Notes</b></span>:
# * Nilai korelasi antara `totalpurchases`, `NumWebPurchases`, `NumCatalogPurchases`, `NumStorePurchases` dengan `Income` menunjukkan angka yang kuat bahwa saat pendapatan meningkat, variabel channel platform pembelian terkait juga cenderung meningkat.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 4.3. Purchase Behaviour </span></b>

# %%
# Box Plot: Web Purchases untuk pelanggan dengan Recency rendah dan tinggi
plt.figure(figsize=(10, 6))
sns.boxplot(x='NumWebPurchases', y='Recency', data=df, palette='Blues')
plt.title('Recency berdasarkan Number dari Web Purchases', fontsize=14)
plt.xlabel('Number of Web Purchases', fontsize=12)
plt.ylabel('Recency', fontsize=12)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: Box plot ini membandingkan distribusi antara Web dengan Recency.
#
# * Ada kecenderungan bahwa pelanggan yang melakukan lebih banyak pembelian web memiliki `Recency` yang lebih rendah, yang berarti mereka lebih aktif dalam melakukan pembelian baru-baru ini.
# * Meskipun ada kecenderungan yang disebutkan, distribusi `Recency` tetap bervariasi secara luas di setiap kategori jumlah pembelian web, menunjukkan bahwa tidak semua pelanggan yang melakukan banyak pembelian web adalah pelanggan yang baru-baru ini aktif.
#
# Box plot ini memberikan gambaran tentang bagaimana Recency terkait dengan jumlah pembelian web, dengan kecenderungan kecil yang menunjukkan bahwa pelanggan dengan lebih banyak pembelian web lebih aktif dalam melakukan pembelian baru-baru ini.

# %%
# Box Plot: perbadnignan katalog Purchases dan off strore Purchases untuk pelanggan dengan Recency rendah dan tinggi
plt.figure(figsize=(10, 6))
sns.boxplot(data=pd.melt(df, id_vars='Recency', value_vars=['NumCatalogPurchases', 'NumStorePurchases']),
            x='variable', y='Recency', hue='value', palette='Reds')
plt.title('Recency bberdasarkan Catalog dan Store Purchases', fontsize=14)
plt.xlabel('Purchase Channel', fontsize=12)
plt.ylabel('Recency', fontsize=12)
plt.legend(title='Number of Purchases', loc='best')
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: box plot yang menunjukkan distribusi Recency berdasarkan Jumlah Pembelian melalui Katalog dan Jumlah Pembelian di Toko.
#
# * Terdapat hubungan yang jelas di mana pelanggan yang melakukan lebih banyak pembelian, baik melalui katalog maupun di toko, cenderung memiliki `Recency` yang lebih rendah. Artinya, mereka baru-baru ini lebih aktif dalam berbelanja.
# * Meskipun ada hubungan yang jelas, variasi dalam `Recency` masih ada, terutama di antara pelanggan dengan jumlah pembelian yang lebih rendah.
#
# Secara sederhananya, ini memberikan wawasan bahwa frekuensi pembelian (baik melalui katalog maupun toko) berhubungan dengan seberapa baru-baru ini pelanggan melakukan pembelian, dengan pelanggan yang lebih sering berbelanja cenderung memiliki `Recency` yang lebih rendah.

# %%
# Menganalisis dampak frekuensi pembelian situs web pada Recency
web_purchase_recency_corr = df[['NumWebPurchases', 'Recency']].corr()

# Menganalisis pola pembelian melalui katalog dan toko offline dalam kaitannya dengan Recency
catalog_purchase_recency_corr = df[['NumCatalogPurchases', 'Recency']].corr()
store_purchase_recency_corr = df[['NumStorePurchases', 'Recency']].corr()

display(web_purchase_recency_corr, catalog_purchase_recency_corr, store_purchase_recency_corr)
# Out:
#                  NumWebPurchases   Recency
# NumWebPurchases  1.000000        -0.008767
# Recency         -0.008767         1.000000
#                      NumCatalogPurchases   Recency
# NumCatalogPurchases  1.000000             0.029487
# Recency              0.029487             1.000000
#                    NumStorePurchases   Recency
# NumStorePurchases  1.000000           0.004754
# Recency            0.004754           1.000000

# %% [markdown]
# <span style='color:green'><b>Notes</b></span>:
# * Korelasi yang sangat lemah (-0.008767) [mendekati nol] antara `NumWebPurchases` dan `Recency` menunjukkan bahwa tidak ada hubungan yang signifikan antara kedua variabel.
# * Korelasi rendah (0.029487) antara `NumCatalogPurchases` dan `Recency`, nilainya masih menunjukkan bahwa tidak ada hubungan linear yang kuat antara jumlah pembelian melalui `Catalog` dan `Recency`.
# * Korelasi (0.004754) sangat dekat dengan nol, menunjukkan bahwa tidak ada hubungan linear yang signifikan antara `NumStorePurchases` dan `Recency`.`Dengan kata lain, seberapa sering pelanggan berbelanja di toko tidak berkaitan erat dengan seberapa baru-baru ini mereka melakukan pembelian.
#
# Artinya, seberapa sering pelanggan berbelanja melalui saluran-saluran ini tidak berkaitan erat dengan seberapa baru-baru ini mereka melakukan pembelian.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 4.4. Promotion Response </span></b>

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Age', 'Generasi', 'Education', 'Marital_Status',
#        'Income', 'Economic_Stat', 'Kidhome', 'Teenhome', 'Dependent',
#        'Dt_Customer', 'Recency', 'Complain', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'mnttotal', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'totalpurchases', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'totalacceptedcmp',
#        'Recency_Category'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['totalacceptedcmp'] > 0, y='Recency', data=df, palette='Blues')
plt.title('Recency berdasarkan Campaign Acceptance', fontsize=14)
plt.xlabel('Accepted Any Campaign', fontsize=12)
plt.ylabel('Recency', fontsize=12)
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: Box Plot Recency berdasarkan Campaign Acceptance.
#
# * Pelanggan yang menerima Campaign pemasaran (Yes) memiliki median `Recency` yang lebih rendah dibandingkan mereka yang tidak menerima Campaign (No).
# * Variasi (IQR) Recency untuk kedua kelompok ini juga berbeda. Pelanggan yang menerima Campaign memiliki distribusi `Recency` yang lebih terpusat pada nilai yang lebih rendah.
#
# ini menunjukkan bahwa pelanggan yang baru-baru ini lebih aktif berbelanja lebih cenderung menerima Campaign pemasaran.

# %%
campaign_columns = ['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5']
average_recency_by_campaign = df[campaign_columns + ['Recency']].groupby(campaign_columns).mean()

average_recency_by_campaign = average_recency_by_campaign.reset_index()
average_recency_by_campaign = average_recency_by_campaign.melt(id_vars=['Recency'], var_name='Campaign', value_name='Accepted')

plt.figure(figsize=(10, 6))
sns.barplot(x='Campaign', y='Recency',  hue='Accepted', data=average_recency_by_campaign, palette='Reds')
plt.title('Average Recency by Campaign Acceptance', fontsize=14)
plt.xlabel('Campaign', fontsize=12)
plt.ylabel('Average Recency', fontsize=12)
plt.legend(title='Accepted', loc='best')
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>: Average Recency berdasarkan Penerimaan Campaign.
#
# * Grafik ini menunjukkan rata-rata `Recency` berdasarkan penerimaan Campaign untuk setiap Campaign yang berbeda (AcceptedCmp1, AcceptedCmp2, dll).
# * Dalam setiap Campaign, pelanggan yang menerima (1) Campaign cenderung memiliki rata-rata `Recency` yang lebih rendah dibandingkan yang tidak menerima(0).
#
# ini menguatkan analisa sebelumnya bahwa pelanggan yang merespons Campaign pemasaran cenderung memiliki interaksi yang lebih baru (`Recency` lebih rendah).

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='NumDealsPurchases', y='Recency', data=df, palette='Blues')
plt.title('Recency by Number of Deals Purchases', fontsize=14)
plt.xlabel('Number of Deals Purchases', fontsize=12)
plt.ylabel('Recency', fontsize=12)
plt.show()

# %% [markdown]
# <span style='color:blue'><b>Notes</b></span>:  Box Plot of Recency by Number of Deals Purchases.
#
# * Box plot ini menunjukkan distribusi `Recency` berdasarkan jumlah Deals Purchases.
# * Meskipun ada sedikit penurunan median `Recency` dengan meningkatnya jumlah Deals Purchases, perbedaan ini tidak signifikan.
#
# Variasi dalam `Recency` tetap besar di semua kategori, yang menunjukkan bahwa jumlah Deals Purchases tidak berkorelasi kuat dengan seberapa baru pelanggan melakukan pembelian.

# %%
# Menilai efektivitas kampanye promosi

# Pengelompokan berdasarkan Response untuk melihat apakah penerimaan promosi dikaitkan dengan Recency yang lebih rendah
promotion_effectiveness = df.groupby('Response')['Recency'].mean().reset_index()

# Menilai efektivitas diskon dalam mengurangi Recency 
discount_effectiveness = df.groupby('totalacceptedcmp')['Recency'].mean().reset_index()

display(promotion_effectiveness, discount_effectiveness)
# Out:
#    Response    Recency
# 0  0         51.514690
# 1  1         35.383234
#    totalacceptedcmp    Recency
# 0  0                 50.895156
# 1  1                 45.697297
# 2  2                 40.464789
# 3  3                 42.921569
# 4  4                 47.388889
# 5  5                 44.600000

# %% [markdown]
# <span style='color:green'><b>Notes</b></span>:
#
# * Pelanggan yang merespons memiliki rata-rata `Recency` yang lebih rendah (35.38) dibandingkan dengan mereka yang tidak merespons dengan rata-rata `Recency` (51.51).
# Ini menunjukkan bahwa pelanggan yang baru-baru ini berbelanja lebih merespons Campaign pemasaran.
# * Rata-rata `Recency` menurun seiring dengan bertambahnya jumlah Campaign yang diterima (`totalacceptedcmp`).
#
# Pelanggan yang menerima lebih banyak Campaign cenderung memiliki `Recency` yang lebih rendah, artinya mereka baru-baru ini lebih aktif terlibat dalam aktivitas yang diukur oleh `Recency`.
# Hal ini menunjukkan bahwa Campaign pemasaran yang diterima oleh pelanggan mempengaruhi seberapa sering mereka berinteraksi atau melakukan pembelian.

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 5 |</span><span style='color:coralred'> Conclusion & Recommendation</span></b>
#
# ____

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 5.1. Data Insight </span></b>
#
# * Analisis ini menunjukkan bahwa sebagian besar pelanggan supermarket ini memiliki nilai `Recency` yang tinggi, menunjukkan bahwa banyak pelanggan yang tidak kembali berbelanja dalam jangka waktu yang lama. Hal ini mengindikasikan potensi `churn` yang signifikan.
# * Pembelian yang dilakukan melalui diskon (`NumDealsPurchases`) menunjukkan tren yang menarik, di mana pelanggan cenderung lebih responsif terhadap Campaign promosi yang diadakan.
# * Channel Platform yang lebih banyak digunakan oleh pelanggan adalah melalui pembelian langsung di toko (`NumStorePurchases`), tetapi ada potensi peningkatan pada penjualan melalui web dan katalog.
#
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 5.2. Bussiness Impact </span></b>
#
# * Tingginya nilai `Recency` berdampak langsung pada tingkat `Churn` yang meningkat, yang dapat mengurangi pendapatan perusahaan jika tidak ditangani dengan baik.
# * Respons positif terhadap Campaign promosi menunjukkan bahwa strategi diskon bisa menjadi alat yang efektif untuk menarik kembali pelanggan yang memiliki nilai `Recency` tinggi.
#
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 5.3. Recomendation </span></b>
#
# * Fokus pada strategi untuk menurunkan nilai `Recency` dengan melakukan Campaign re-engagement yang ditargetkan kepada pelanggan yang tidak aktif selama lebih dari 30 hari.
# * Tingkatkan frekuensi dan variasi Campaign promosi untuk mendorong pelanggan melakukan pembelian lagi, dan hasil data Campaign yang berhasil dapat dianalisis lebih lanjut untuk ditingkatkan.
# * Perkuat strategi omnichannel Operational dengan memperbaiki pengalaman belanja online dan katalog, sekaligus meningkatkan integrasi antara penjualan online dan toko fisik.
#
# <a id="basic"></a>
# ### <b><span style='color:coralred'> 5.4. Future Planning </span></b>
#
# * Langkah 1: Identifikasi segmen pelanggan dengan nilai `Recency` yang tinggi dan kirimkan Campaign re-engagement yang dipersonalisasi (User Generated Context).
# * Langkah 2: Jalankan analisis A/B testing untuk menentukan jenis promosi yang paling efektif dan implementasikan di seluruh segmen yang relevan.
# * Langkah 3: Investasikan dalam peningkatan infrastruktur e-commerce dan pelatihan staf untuk memastikan pengalaman belanja online yang mulus dan terintegrasi dengan penjualan di toko fisik.
#
# Project untuk Tim pemasaran dan penjualan, didukung oleh tim IT.
